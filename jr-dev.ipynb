# %% [markdown]
# # GPT, Junior Developer
#
# Let's see if we can get GPT to fix bugs.

# %% [markdown]
# # Init

# %%
import logging
import os
import sys

from dotenv import load_dotenv

# for jupyter notebooks
import nest_asyncio
from IPython.display import display, Markdown
###

from llama_index.langchain_helpers.text_splitter import TokenTextSplitter
from llama_index import Document, GPTListIndex

from alchemy.loader import ModelOptions, RepoOptions, CacheOptions

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

load_dotenv()

assert (os.environ["GITHUB_TOKEN"] and os.environ["OPENAI_API_KEY"])

nest_asyncio.apply()

# common options
repo_opts = RepoOptions(owner="inhumantsar", repo="tacostats")
# setting this to True forces a cache update on every run.
# useful for testing but it's not free! watch your token usage.
cache_opts = CacheOptions(force_update=True)

# primer data for the chat model
# PREHISTORY = [
#     "You are a software developer helping to refactor, improve, and maintain a codebase.",
#     "When prompted to perform an update, you must return the entire updated file.",
#     "Format your responses as plaintext without markdown, as if you were editing the file directly.",
# ]
# splitter = TokenTextSplitter(separator=" ", chunk_size=2048, chunk_overlap=20)
# prehistory_chunks = [splitter.split_text(prehistory) for prehistory in PREHISTORY]
#
# ... i thought loading this into the memory index would work, but apparently it does stuff in the translating
# subclasses into the base class before storing or feeding them into the agent. it does an isinstance check
# and fails. so i'm just going to use a prompt template instead...
PROMPT_TEMPLATE = """
You are a software developer helping to refactor, improve, and maintain a codebase. When prompted to 
perform an update, you must return the entire updated file. Format your responses as plaintext without 
markdown, as if you were editing the file directly.
{chat_history}
Human: {question}
AI:
"""

# the "github issue" we're going to simulate
PROMPT = "Update the memory size for all harvester-related functions in lambda.template.yaml to 512mb."

# %% [markdown]
# # gpt-3.5-turbo

# %% [markdown]
# ## Options

# %%
# this goes into the service context and it seems like this cannot be changed after the index is created
gpt35t_model_opts = ModelOptions(model_name="gpt-3.5-turbo", temperature=0.2)

# %% [markdown]
# ## Create index

# %%
from alchemy.loader import create_simple_vector_index
gpt35t_index = create_simple_vector_index(repo_opts, cache_opts, gpt35t_model_opts)
# Out:
# INFO:alchemy.loader:loading simple vector index...
# loading simple vector index...
# loading simple vector index...
# INFO:alchemy.loader:repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# INFO:alchemy.loader:cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# INFO:alchemy.loader:model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-3.5-turbo', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': None, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-3.5-turbo', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': None, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-3.5-turbo', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': None, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# WARNING:llama_index.llm_predictor.base:Unknown max input size for gpt-3.5-turbo, using defaults.
# Unknown max input size for gpt-3.5-turbo, using defaults.
# Unknown max input size for gpt-3.5-turbo, using defaults.
# current path:
# tree data: GitTreeResponseModel(sha='9158e2d024c169d29eb94fdd327b724402381cb0', url='https://api.github.com/repos/inhumantsar/tacostats/git/trees/9158e2d024c169d29eb94fdd327b724402381cb0', tree=[GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), GitTreeResponseModel.GitTreeObject(path='.gitignore', mode='100644', type='blob', sha='fe1c09354be3309cbe42fc37d3c9818a933bde11', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fe1c09354be3309cbe42fc37d3c9818a933bde11', size=73), GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300), GitTreeResponseModel.GitTreeObject(path='requirements_dev.txt', mode='100644', type='blob', sha='b14d6b52b283fde18c8319b217ba6513af8f2487', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b14d6b52b283fde18c8319b217ba6513af8f2487', size=44) ...
# processing tree 9158e2d024c169d29eb94fdd327b724402381cb0
# Checking .bumpversion.cfg whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if .bumpversion.cfg is not a subdirectory of any of the filter directories
# Checking .bumpversion.cfg whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199)
# found blob .bumpversion.cfg
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg')]
# Checking .dockerignore whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if .dockerignore is not a subdirectory of any of the filter directories
# Checking .dockerignore whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75)
# found blob .dockerignore
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore')]
# Checking .gitignore whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if .gitignore is not a subdirectory of any of the filter directories
# ignoring .gitignore due to filter
# Checking .python-version whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if .python-version is not a subdirectory of any of the filter directories
# Checking .python-version whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10)
# found blob .python-version
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version')]
# Checking README.md whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if README.md is not a subdirectory of any of the filter directories
# Checking README.md whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841)
# found blob README.md
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md')]
# Checking VERSION whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if VERSION is not a subdirectory of any of the filter directories
# Checking VERSION whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5)
# found blob VERSION
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION')]
# Checking deploy.ps1 whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if deploy.ps1 is not a subdirectory of any of the filter directories
# Checking deploy.ps1 whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472)
# found blob deploy.ps1
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1')]
# Checking deploy.sh whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if deploy.sh is not a subdirectory of any of the filter directories
# Checking deploy.sh whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420)
# found blob deploy.sh
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh')]
# Checking lambda.Dockerfile whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if lambda.Dockerfile is not a subdirectory of any of the filter directories
# Checking lambda.Dockerfile whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438)
# found blob lambda.Dockerfile
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile')]
# Checking lambda.cloudformation.yaml whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if lambda.cloudformation.yaml is not a subdirectory of any of the filter directories
# Checking lambda.cloudformation.yaml whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475)
# found blob lambda.cloudformation.yaml
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml')]
# Checking lambda.env whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if lambda.env is not a subdirectory of any of the filter directories
# Checking lambda.env whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143)
# found blob lambda.env
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env')]
# Checking lambda.template.yaml whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if lambda.template.yaml is not a subdirectory of any of the filter directories
# Checking lambda.template.yaml whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347)
# found blob lambda.template.yaml
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml')]
# Checking pyproject.toml whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if pyproject.toml is not a subdirectory of any of the filter directories
# Checking pyproject.toml whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31)
# found blob pyproject.toml
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml'), (GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), 'pyproject.toml')]
# Checking requirements.txt whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if requirements.txt is not a subdirectory of any of the filter directories
# Checking requirements.txt whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300)
# found blob requirements.txt
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml'), (GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), 'pyproject.toml'), (GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300), 'requirements.txt')]
# Checking requirements_dev.txt whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if requirements_dev.txt is not a subdirectory of any of the filter directories
# Checking requirements_dev.txt whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='requirements_dev.txt', mode='100644', type='blob', sha='b14d6b52b283fde18c8319b217ba6513af8f2487', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b14d6b52b283fde18c8319b217ba6513af8f2487', size=44)
# found blob requirements_dev.txt
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml'), (GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), 'pyproject.toml'), (GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300), 'requirements.txt'), (GitTreeResponseModel.GitTreeObject(path='requirements_dev.txt', mode='100644', type='blob', sha='b14d6b52b283fde18c8319b217ba6513af8f2487', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b14d6b52b283fde18c8319b217ba6513af8f2487', size=44), 'requirements_dev.txt')]
# Checking samconfig.toml whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if samconfig.toml is not a subdirectory of any of the filter directories
# Checking samconfig.toml whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='samconfig.toml', mode='100644', type='blob', sha='7a126942fdb22f9e79937a3c035a2c3fef322a1d', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/7a126942fdb22f9e79937a3c035a2c3fef322a1d', size=799)
# found blob samconfig.toml
# ...
# Checking test whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if test is not a subdirectory of any of the filter directories
# tree object: GitTreeResponseModel.GitTreeObject(path='test', mode='040000', type='tree', sha='5f64dbad1fb44d227cb11c058aaa099e0951265a', url='https://api.github.com/repos/inhumantsar/tacostats/git/trees/5f64dbad1fb44d227cb11c058aaa099e0951265a', size=None)
# recursing into test
# 	current path: test
# 	tree data: GitTreeResponseModel(sha='5f64dbad1fb44d227cb11c058aaa099e0951265a', url='https://api.github.com/repos/inhumantsar/tacostats/git/trees/5f64dbad1fb44d227cb11c058aaa099e0951265a', tree=[GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0), GitTreeResponseModel.GitTreeObject(path='test_statsio.py', mode='100644', type='blob', sha='6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', size=1245), GitTreeResponseModel.GitTreeObject(path='utils.py', mode='100644', type='blob', sha='aa9b5cc71b8be91a5642833601877d05922562fd', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/aa9b5cc71b8be91a5642833601877d05922562fd', size=348)], truncated=False)
# 	processing tree 5f64dbad1fb44d227cb11c058aaa099e0951265a
# Checking test/__init__.py whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if test/__init__.py is not a subdirectory of any of the filter directories
# Checking test/__init__.py whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# 	tree object: GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0)
# 	found blob __init__.py
# 	blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0), 'test/__init__.py')]
# Checking test/test_statsio.py whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if test/test_statsio.py is not a subdirectory of any of the filter directories
# Checking test/test_statsio.py whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# 	tree object: GitTreeResponseModel.GitTreeObject(path='test_statsio.py', mode='100644', type='blob', sha='6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', size=1245)
# 	found blob test_statsio.py
# 	blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0), 'test/__init__.py'), (GitTreeResponseModel.GitTreeObject(path='test_statsio.py', mode='100644', type='blob', sha='6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', size=1245), 'test/test_statsio.py')]
# Checking test/utils.py whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if test/utils.py is not a subdirectory of any of the filter directories
# Checking test/utils.py whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# 	tree object: GitTreeResponseModel.GitTreeObject(path='utils.py', mode='100644', type='blob', sha='aa9b5cc71b8be91a5642833601877d05922562fd', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/aa9b5cc71b8be91a5642833601877d05922562fd', size=348)
# 	found blob utils.py
# 	blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0), 'test/__init__.py'), (GitTreeResponseModel.GitTreeObject(path='test_statsio.py', mode='100644', type='blob', sha='6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', size=1245), 'test/test_statsio.py'), (GitTreeResponseModel.GitTreeObject(path='utils.py', mode='100644', type='blob', sha='aa9b5cc71b8be91a5642833601877d05922562fd', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/aa9b5cc71b8be91a5642833601877d05922562fd', size=348), 'test/utils.py')]
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml'), (GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), 'pyproject.toml'), (GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300), 'requirements.txt'), (GitTreeResponseModel.GitTreeObject(path='requirements_dev.txt', mode='100644', type='blob', sha='b14d6b52b283fde18c8319b217ba6513af8f2487', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b14d6b52b283fde18c8319b217ba6513af8f2487', size=44), 'requirements_dev.txt'), (GitTreeResponseModel.GitTreeObject(path='samconfig.toml', mode='100644', type='blob', sha='7a126942fdb22f9e79937a3c035a2c3fef322a1d', ...
# got 36 blobs
# Time to get blobs ([('.bumpversion.cfg', 199), ('.dockerignore', 75), ('.python-version', 10), ('README.md', 841), ('VERSION', 5), ('deploy.ps1', 472), ('deploy.sh', 420), ('lambda.Dockerfile', 438), ('lambda.cloudformation.yaml', 1475), ('lambda.env', 143)]): 0.67 seconds
# generating document for .bumpversion.cfg
# got 199 characters- adding to documents - .bumpversion.cfg
# generating document for .dockerignore
# got 75 characters- adding to documents - .dockerignore
# generating document for .python-version
# got 10 characters- adding to documents - .python-version
# generating document for README.md
# got 841 characters- adding to documents - README.md
# generating document for VERSION
# got 5 characters- adding to documents - VERSION
# generating document for deploy.ps1
# got 472 characters- adding to documents - deploy.ps1
# generating document for deploy.sh
# got 420 characters- adding to documents - deploy.sh
# generating document for lambda.Dockerfile
# got 438 characters- adding to documents - lambda.Dockerfile
# generating document for lambda.cloudformation.yaml
# got 1475 characters- adding to documents - lambda.cloudformation.yaml
# generating document for lambda.env
# got 143 characters- adding to documents - lambda.env
# Time to get blobs ([('lambda.template.yaml', 6347), ('pyproject.toml', 31), ('requirements.txt', 300), ('requirements_dev.txt', 44), ('samconfig.toml', 799), ('__init__.py', 0), ('config.py', 6247), ('harvester.py', 1019), ('keywords.py', 8017), ('__init__.py', 0)]): 0.67 seconds
# generating document for lambda.template.yaml
# got 6347 characters- adding to documents - lambda.template.yaml
# generating document for pyproject.toml
# got 31 characters- adding to documents - pyproject.toml
# generating document for requirements.txt
# got 300 characters- adding to documents - requirements.txt
# generating document for requirements_dev.txt
# got 44 characters- adding to documents - requirements_dev.txt
# generating document for samconfig.toml
# got 799 characters- adding to documents - samconfig.toml
# generating document for tacostats/__init__.py
# got 0 characters- adding to documents - tacostats/__init__.py
# generating document for tacostats/config.py
# got 6246 characters- adding to documents - tacostats/config.py
# generating document for tacostats/harvester.py
# got 1019 characters- adding to documents - tacostats/harvester.py
# generating document for tacostats/keywords.py
# got 8017 characters- adding to documents - tacostats/keywords.py
# generating document for tacostats/reddit/__init__.py
# got 0 characters- adding to documents - tacostats/reddit/__init__.py
# Time to get blobs ([('dt.py', 7452), ('report.py', 2162), ('stats.py', 12137), ('__init__.py', 1322), ('local.py', 1802), ('s3.py', 3784), ('census.md.j2', 413), ('keywords.md.j2', 990), ('memeiest.md.j2', 1138), ('template.md.j2', 4579)]): 0.86 seconds
# generating document for tacostats/reddit/dt.py
# got 7452 characters- adding to documents - tacostats/reddit/dt.py
# generating document for tacostats/reddit/report.py
# got 2162 characters- adding to documents - tacostats/reddit/report.py
# generating document for tacostats/stats.py
# got 12121 characters- adding to documents - tacostats/stats.py
# generating document for tacostats/statsio/__init__.py
# got 1322 characters- adding to documents - tacostats/statsio/__init__.py
# generating document for tacostats/statsio/local.py
# got 1802 characters- adding to documents - tacostats/statsio/local.py
# generating document for tacostats/statsio/s3.py
# got 3784 characters- adding to documents - tacostats/statsio/s3.py
# generating document for tacostats/templates/census.md.j2
# got 397 characters- adding to documents - tacostats/templates/census.md.j2
# generating document for tacostats/templates/keywords.md.j2
# got 985 characters- adding to documents - tacostats/templates/keywords.md.j2
# generating document for tacostats/templates/memeiest.md.j2
# got 1121 characters- adding to documents - tacostats/templates/memeiest.md.j2
# generating document for tacostats/templates/template.md.j2
# got 4381 characters- adding to documents - tacostats/templates/template.md.j2
# Time to get blobs ([('userstats.md.j2', 971), ('userstats.py', 6996), ('util.py', 1395), ('__init__.py', 0), ('test_statsio.py', 1245), ('utils.py', 348)]): 0.53 seconds
# generating document for tacostats/templates/userstats.md.j2
# got 971 characters- adding to documents - tacostats/templates/userstats.md.j2
# generating document for tacostats/userstats.py
# got 6996 characters- adding to documents - tacostats/userstats.py
# generating document for tacostats/util.py
# got 1377 characters- adding to documents - tacostats/util.py
# generating document for test/__init__.py
# got 0 characters- adding to documents - test/__init__.py
# generating document for test/test_statsio.py
# got 1245 characters- adding to documents - test/test_statsio.py
# generating document for test/utils.py
# got 348 characters- adding to documents - test/utils.py
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total embedding token usage: 32893 tokens
# > [build_index_from_nodes] Total embedding token usage: 32893 tokens
# > [build_index_from_nodes] Total embedding token usage: 32893 tokens

# %% [markdown]
# ## Simulate a GitHub issue

# %% [markdown]
# ### Method 1: Querying the Index Directly
#
# This seems to have yielded the best results so far. It reliably knows what to do with the prompt and when prodded, it will output the entire file. It's not perfect, but it's about what i would expect of chatgpt.
#
# However it's SLOW AS FUCK and seems to consume a lot of tokens on every call. Not ideal.

# %%
from llama_index import QueryMode
resp = gpt35t_index.query(f"{PROMPT}. Pretend you are actually updating the file yourself and respond with the updated contents of the file in its entirety. Do not use markdown.", verbose=True)
# logger.info(resp)
display(resp.response)
# Out:
# > Got node text: file_path: lambda.template.yaml
# file_name: lambda.template.yaml
#
# AWSTemplateFormatVersion: "2010-09-09"
# Transform: AWS::Serverless-2016-10-31
# Description: >
#   tacostats v1.5.4
#
#   periodically ...
# INFO:llama_index.token_counter.token_counter:> [query] Total LLM token usage: 6000 tokens
# > [query] Total LLM token usage: 6000 tokens
# > [query] Total LLM token usage: 6000 tokens
# > [query] Total LLM token usage: 6000 tokens
# > [query] Total LLM token usage: 6000 tokens
# INFO:llama_index.token_counter.token_counter:> [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# 'AWSTemplateFormatVersion: "2010-09-09"\r\nTransform: AWS::Serverless-2016-10-31\r\nDescription: >\r\n  tacostats v1.5.4\r\n\r\n  periodically grab comments from the r/neoliberal DT and gather some basic statistics\r\n\r\n# More info about Globals: https://github.com/awslabs/serverless-application-model/blob/master/docs/globals.rst\r\nGlobals:\r\n  Function:\r\n    Timeout: 900\r\n\r\nResources:\r\n  ###############\r\n  # Harvester\r\n  ###############\r\n  Harvester:\r\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction\r\n    Properties:\r\n      PackageType: Image\r\n      MemorySize: 512 # Updated memory size\r\n      ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4\r\n      ImageConfig:\r\n        Command:\r\n          - tacostats.harvester.lambda_handler\r\n      Role: arn:aws:iam::390721581096:role/tacostats\r\n      Events:\r\n        Cron:\r\n          Type: Schedule\r\n          Properties:\r\n            Schedule: cron(55/30 * * * ? *)\r\n            Enabled: True\r\n    Metadata:\r\n      Dockerfile: lambda.Dockerfile\r\n      DockerContext: "."\r\n\r\n  # post a recap of yesterday\'s stats in the morning\r\n  HarvesterRecap:\r\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction\r\n    Properties:\r\n      PackageType: Image\r\n      MemorySize: 512 # Updated memory size\r\n      ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4\r\n      ImageConfig:\r\n        Command:\r\n          - tacostats.harvester.lambda_handler\r\n      Environment:\r\n        Variables:\r\n          RECAP: True\r\n      Role: arn:aws:iam::390721581096:role/tacostats\r\n      Events:\r\n        Cron:\r\n          Type: Schedule\r\n          Properties:\r\n            Schedule: cron(0 7 * * ? *)\r\n            Enabled: True\r\n    Metadata:\r\n      Dockerfile: lambda.Dockerfile\r\n      DockerContext: "."\r\n\r\n  ###############\r\n  # Statistics\r\n  ###############\r\n  Stats:\r\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction\r\n    Properties:\r\n      PackageType: Image\r\n      MemorySize: 256\r\n      ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4\r\n      ImageConfig:\r\n        Command:\r\n          - tacostats.stats.lambda_handler\r\n      Role: arn:aws:iam::390721581096:role/tacostats\r\n      Environment:\r\n        Variables:\r\n          USE_EXISTING: True\r\n      Events:\r\n        # schedules in utc, et equivs: 12,16,21\r\n        Cron:\r\n          Type: Schedule\r\n          Properties:\r\n            Schedule: cron(0 16,22,1 * * ? *)\r\n            Enabled: True\r\n    Metadata:\r\n      Dockerfile: lambda.Dockerfile\r\n      DockerContext: "."\r\n\r\n  # post a recap of yesterday\'s stats in the morning\r\n  StatsRecap:\r\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction\r\n    Properties:\r\n      PackageType: Image\r\n      MemorySize: 256\r\n      ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4\r\n      ImageConfig:\r\n        Command:\r\n          - tacostats.stats.lambda_handler\r\n      Environment:\r\n        Variables:\r\n          RECAP: True\r\n          USE_EXISTING: True\r\n      Role: arn:aws:iam::390721581096:role/tacostats\r\n      Events:\r\n        # schedules in utc, 9et\r\n        Cron:\r\n          Type: Schedule\r\n          Properties:\r\n            Schedule: cron(0 13 * * ? *)\r\n            Enabled: True\r\n    Metadata:\r\n      Dockerfile: lambda.Dockerfile\r\n     ...

# %% [markdown]
# ### Method 2: Using langchain's GPTIndex tools
#
# The general idea here is to provide a chat agent with a set of "tools", ie: our file index.
#
# This is supposed to be the best way to do it as it would behave more like ChatGPT's plugin system, but as you'll see, it doesn't actually work that well.
#
# The best result that I got consistently was actually two separate responses. The first would say "You can update the memorysize by blahblahblah". When prompted a second time with "cool but just do it k?" it would flip between "but i'm just an LLM i can't actually write files" and outputting snippets in code blocks (despite the prompt specifically requesting it not to).
#
# Results were same or worse with different memory types, response types, and prompt templates.
#
# I suspect that some of langchain's abstraction magic is getting in my way here but I'm not sure how to get it to behave the way I'd expect it to.

# %%
from dataclasses import asdict
from langchain.agents import Tool
from langchain.agents.agent_types import AgentType
from langchain.chains.conversation.memory import ConversationBufferMemory
from langchain.chat_models import ChatOpenAI
from langchain.agents import initialize_agent
from llama_index.langchain_helpers.memory_wrapper import GPTIndexChatMemory
# from langchain.schema import ChatMessage

### it really didn't react well to having both an index memory like this and an index tool at the same time...
# gpt35t_memory_index = GPTListIndex([])
# gpt35t_memory = GPTIndexChatMemory(
#     index=gpt35t_memory_index, 
#     memory_key="chat_history", 
#     query_kwargs={"response_mode": "compact"},
#     # return_source returns source nodes instead of querying index
#     return_source=True,
#     # return_messages returns context in message format
#     return_messages=True
# )
gpt35t_memory = ConversationBufferMemory(memory_key="chat_history")
gpt35t_tools = [
        Tool(
            name = "GPT Index",
            func=lambda q: str(gpt35t_index.query(q)),
            description="these are the files you will need to update.",
            return_direct=True,
        )
    ]
gpt35t_model = ChatOpenAI(
    **{k: v for k, v in asdict(gpt35t_model_opts).items() if v},
)
gpt35t_agent_chain = initialize_agent(
    gpt35t_tools, 
    gpt35t_model, 
    agent=AgentType.CHAT_CONVERSATIONAL_REACT_DESCRIPTION, 
    memory=gpt35t_memory,
    prompt_template=PROMPT_TEMPLATE,
    verbose=True,
)

# %%
gpt35t_agent_chain.run(input=PROMPT)

# %%
gpt35t_agent_chain.run(input="that's great now output the updated file in its entirety as a code block")

# %% [markdown]
# ### Results
#
# Well, gpt-3.5-turbo definitely updated the memory size, but it missed the "harvester-related" part and updated *all* functions. In other runs it bumped up MemorySize seemingly at random. Once it also added MemorySize to the Function globals. While I didn't run them to check, all of the generated code seemed to at least be syntactically correct even they didn't meet the requirements.

# %% [raw]
# AWSTemplateFormatVersion: "2010-09-09"
# Transform: AWS::Serverless-2016-10-31
# Description: >
#   tacostats v1.5.4
#
#   periodically grab comments from the r/neoliberal DT and gather some basic statistics
#
# # More info about Globals: https://github.com/awslabs/serverless-application-model/blob/master/docs/globals.rst
# Globals:
#   Function:
#     Timeout: 900
#
# Resources:
#   ###############
#   # Harvester
#   ###############
#   Harvester:
#     Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction
#     Properties:
#       PackageType: Image
#       MemorySize: 512  # updated memory size
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.harvester.lambda_handler
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(55/30 * * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   # post a recap of yesterday's stats in the morning
#   HarvesterRecap:
#     Type: AWS::Serverless::Function
#     Properties:
#       PackageType: Image
#       MemorySize: 512  # updated memory size
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.harvester.lambda_handler
#       Environment:
#         Variables:
#           RECAP: True
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(0 7 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   ###############
#   # Statistics
#   ###############
#   Stats:
#     Type: AWS::Serverless::Function
#     Properties:
#       PackageType: Image
#       MemorySize: 512  # updated memory size
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.stats.lambda_handler
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Environment:
#         Variables:
#           USE_EXISTING: True
#       Events:
#         # schedules in utc, et equivs: 12,16,21
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(0 16,22,1 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   # post a recap of yesterday's stats in the morning
#   StatsRecap:
#     Type: AWS::Serverless::Function
#     Properties:
#       PackageType: Image
#       MemorySize: 512  # updated memory size
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.stats.lambda_handler
#       Environment:
#         Variables:
#           RECAP: True
#           USE_EXISTING: True
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         # schedules in utc, 9et
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(0 13 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   ###############
#   # Keywords
#   ###############
#   Keywords:
#     Type: AWS::Serverless::Function
#     Properties:
#       PackageType: Image
#       MemorySize: 512  # updated memory size
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.keywords.lambda_handler
#       Environment:
#         Variables:
#           USE_EXISTING: True
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(20 20 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   # post a recap of yesterday's keywords in the morning
#   KeywordsRecap:
#     Type: AWS::Serverless::Function
#     Properties:
#       PackageType: Image
#       MemorySize: 512  # updated memory size
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.keywords.lambda_handler
#       Environment:
#         Variables:
#           RECAP: True
#           USE_EXISTING: True
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         # schedules in utc, 10et
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(0 14 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   ###############
#   # UserStats
#   ###############
#   UserStats:
#     Type: AWS::Serverless::Function
#     Properties:
#       Timeout: 300
#       PackageType: Image
#       MemorySize: 512  # updated memory size
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.userstats.lambda_handler
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         Queue:
#           Type: SQS
#           Properties:
#             Queue: arn:aws:sqs:us-east-2:390721581096:tacostats-pinger
#             BatchSize: 10
#             Enabled: true
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."

# %% [markdown]
# # gpt-4

# %% [markdown]
# ## Options

# %%
# this goes into the service context and it seems like this cannot be changed after the index is created
gpt4_model_opts = ModelOptions(model_name="gpt-4", temperature=0.2, request_timeout=600)

# %% [markdown]
# ## Create index

# %%
from alchemy.loader import create_simple_vector_index
gpt4_index = create_simple_vector_index(repo_opts, cache_opts, gpt4_model_opts)
# Out:
# INFO:alchemy.loader:loading simple vector index...
# loading simple vector index...
# loading simple vector index...
# loading simple vector index...
# loading simple vector index...
# loading simple vector index...
# loading simple vector index...
# INFO:alchemy.loader:repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# repo_opts: {'owner': 'inhumantsar', 'repo': 'tacostats', 'branch': 'main', 'commit_sha': None, 'filter_directories': (['.git', '.yarn', 'node_modules'], <FilterType.EXCLUDE: 1>), 'filter_file_extensions': (['.zip'], <FilterType.EXCLUDE: 1>), 'verbose': True, 'concurrent_requests': 10}
# INFO:alchemy.loader:cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# cache_opts: {'path': '~/.alchemy', 'force_update': True, 'max_age': 60}
# INFO:alchemy.loader:model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-4', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': 600, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-4', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': 600, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-4', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': 600, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-4', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': 600, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-4', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': 600, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-4', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': 600, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# model_opts: {'cache': None, 'verbose': False, 'model_name': 'gpt-4', 'temperature': 0.2, 'max_tokens': None, 'top_p': None, 'frequency_penalty': None, 'presence_penalty': None, 'n': None, 'best_of': None, 'model_kwargs': None, 'openai_api_key': None, 'batch_size': None, 'request_timeout': 600, 'logit_bias': None, 'max_retries': None, 'streaming': False}
# current path:
# tree data: GitTreeResponseModel(sha='9158e2d024c169d29eb94fdd327b724402381cb0', url='https://api.github.com/repos/inhumantsar/tacostats/git/trees/9158e2d024c169d29eb94fdd327b724402381cb0', tree=[GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), GitTreeResponseModel.GitTreeObject(path='.gitignore', mode='100644', type='blob', sha='fe1c09354be3309cbe42fc37d3c9818a933bde11', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fe1c09354be3309cbe42fc37d3c9818a933bde11', size=73), GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300), GitTreeResponseModel.GitTreeObject(path='requirements_dev.txt', mode='100644', type='blob', sha='b14d6b52b283fde18c8319b217ba6513af8f2487', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b14d6b52b283fde18c8319b217ba6513af8f2487', size=44) ...
# processing tree 9158e2d024c169d29eb94fdd327b724402381cb0
# Checking .bumpversion.cfg whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if .bumpversion.cfg is not a subdirectory of any of the filter directories
# Checking .bumpversion.cfg whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199)
# found blob .bumpversion.cfg
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg')]
# Checking .dockerignore whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if .dockerignore is not a subdirectory of any of the filter directories
# Checking .dockerignore whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75)
# found blob .dockerignore
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore')]
# Checking .gitignore whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if .gitignore is not a subdirectory of any of the filter directories
# ignoring .gitignore due to filter
# Checking .python-version whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if .python-version is not a subdirectory of any of the filter directories
# Checking .python-version whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10)
# found blob .python-version
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version')]
# Checking README.md whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if README.md is not a subdirectory of any of the filter directories
# Checking README.md whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841)
# found blob README.md
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md')]
# Checking VERSION whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if VERSION is not a subdirectory of any of the filter directories
# Checking VERSION whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5)
# found blob VERSION
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION')]
# Checking deploy.ps1 whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if deploy.ps1 is not a subdirectory of any of the filter directories
# Checking deploy.ps1 whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472)
# found blob deploy.ps1
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1')]
# Checking deploy.sh whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if deploy.sh is not a subdirectory of any of the filter directories
# Checking deploy.sh whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420)
# found blob deploy.sh
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh')]
# Checking lambda.Dockerfile whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if lambda.Dockerfile is not a subdirectory of any of the filter directories
# Checking lambda.Dockerfile whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438)
# found blob lambda.Dockerfile
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile')]
# Checking lambda.cloudformation.yaml whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if lambda.cloudformation.yaml is not a subdirectory of any of the filter directories
# Checking lambda.cloudformation.yaml whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475)
# found blob lambda.cloudformation.yaml
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml')]
# Checking lambda.env whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if lambda.env is not a subdirectory of any of the filter directories
# Checking lambda.env whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143)
# found blob lambda.env
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env')]
# Checking lambda.template.yaml whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if lambda.template.yaml is not a subdirectory of any of the filter directories
# Checking lambda.template.yaml whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347)
# found blob lambda.template.yaml
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml')]
# Checking pyproject.toml whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if pyproject.toml is not a subdirectory of any of the filter directories
# Checking pyproject.toml whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31)
# found blob pyproject.toml
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml'), (GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), 'pyproject.toml')]
# Checking requirements.txt whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if requirements.txt is not a subdirectory of any of the filter directories
# Checking requirements.txt whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300)
# found blob requirements.txt
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml'), (GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), 'pyproject.toml'), (GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300), 'requirements.txt')]
# Checking requirements_dev.txt whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if requirements_dev.txt is not a subdirectory of any of the filter directories
# Checking requirements_dev.txt whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='requirements_dev.txt', mode='100644', type='blob', sha='b14d6b52b283fde18c8319b217ba6513af8f2487', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b14d6b52b283fde18c8319b217ba6513af8f2487', size=44)
# found blob requirements_dev.txt
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml'), (GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), 'pyproject.toml'), (GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300), 'requirements.txt'), (GitTreeResponseModel.GitTreeObject(path='requirements_dev.txt', mode='100644', type='blob', sha='b14d6b52b283fde18c8319b217ba6513af8f2487', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b14d6b52b283fde18c8319b217ba6513af8f2487', size=44), 'requirements_dev.txt')]
# Checking samconfig.toml whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if samconfig.toml is not a subdirectory of any of the filter directories
# Checking samconfig.toml whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# tree object: GitTreeResponseModel.GitTreeObject(path='samconfig.toml', mode='100644', type='blob', sha='7a126942fdb22f9e79937a3c035a2c3fef322a1d', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/7a126942fdb22f9e79937a3c035a2c3fef322a1d', size=799)
# found blob samconfig.toml
# ...
# Checking test whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if test is not a subdirectory of any of the filter directories
# tree object: GitTreeResponseModel.GitTreeObject(path='test', mode='040000', type='tree', sha='5f64dbad1fb44d227cb11c058aaa099e0951265a', url='https://api.github.com/repos/inhumantsar/tacostats/git/trees/5f64dbad1fb44d227cb11c058aaa099e0951265a', size=None)
# recursing into test
# 	current path: test
# 	tree data: GitTreeResponseModel(sha='5f64dbad1fb44d227cb11c058aaa099e0951265a', url='https://api.github.com/repos/inhumantsar/tacostats/git/trees/5f64dbad1fb44d227cb11c058aaa099e0951265a', tree=[GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0), GitTreeResponseModel.GitTreeObject(path='test_statsio.py', mode='100644', type='blob', sha='6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', size=1245), GitTreeResponseModel.GitTreeObject(path='utils.py', mode='100644', type='blob', sha='aa9b5cc71b8be91a5642833601877d05922562fd', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/aa9b5cc71b8be91a5642833601877d05922562fd', size=348)], truncated=False)
# 	processing tree 5f64dbad1fb44d227cb11c058aaa099e0951265a
# Checking test/__init__.py whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if test/__init__.py is not a subdirectory of any of the filter directories
# Checking test/__init__.py whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# 	tree object: GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0)
# 	found blob __init__.py
# 	blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0), 'test/__init__.py')]
# Checking test/test_statsio.py whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if test/test_statsio.py is not a subdirectory of any of the filter directories
# Checking test/test_statsio.py whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# 	tree object: GitTreeResponseModel.GitTreeObject(path='test_statsio.py', mode='100644', type='blob', sha='6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', size=1245)
# 	found blob test_statsio.py
# 	blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0), 'test/__init__.py'), (GitTreeResponseModel.GitTreeObject(path='test_statsio.py', mode='100644', type='blob', sha='6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', size=1245), 'test/test_statsio.py')]
# Checking test/utils.py whether to FilterType.EXCLUDE it based on the filter directories: ['.git', '.yarn', 'node_modules']
# Checking if test/utils.py is not a subdirectory of any of the filter directories
# Checking test/utils.py whether to FilterType.EXCLUDE it based on the filter file extensions: ['.zip']
# 	tree object: GitTreeResponseModel.GitTreeObject(path='utils.py', mode='100644', type='blob', sha='aa9b5cc71b8be91a5642833601877d05922562fd', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/aa9b5cc71b8be91a5642833601877d05922562fd', size=348)
# 	found blob utils.py
# 	blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='__init__.py', mode='100644', type='blob', sha='e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391', size=0), 'test/__init__.py'), (GitTreeResponseModel.GitTreeObject(path='test_statsio.py', mode='100644', type='blob', sha='6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6a16694f4f3f9e272a4fb4f81419a42f3bbe2ead', size=1245), 'test/test_statsio.py'), (GitTreeResponseModel.GitTreeObject(path='utils.py', mode='100644', type='blob', sha='aa9b5cc71b8be91a5642833601877d05922562fd', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/aa9b5cc71b8be91a5642833601877d05922562fd', size=348), 'test/utils.py')]
# blob and full paths: [(GitTreeResponseModel.GitTreeObject(path='.bumpversion.cfg', mode='100644', type='blob', sha='e17f6921b0bc7604766dd58489eda60652564cc0', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/e17f6921b0bc7604766dd58489eda60652564cc0', size=199), '.bumpversion.cfg'), (GitTreeResponseModel.GitTreeObject(path='.dockerignore', mode='100644', type='blob', sha='f0ef4d8ac83ceb8113228e39d491d8043df4da22', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/f0ef4d8ac83ceb8113228e39d491d8043df4da22', size=75), '.dockerignore'), (GitTreeResponseModel.GitTreeObject(path='.python-version', mode='100644', type='blob', sha='fbb3f6d764a9a4d94615db37bc57ffc3a6489503', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/fbb3f6d764a9a4d94615db37bc57ffc3a6489503', size=10), '.python-version'), (GitTreeResponseModel.GitTreeObject(path='README.md', mode='100644', type='blob', sha='2c04052114607993bf069cf8d75686b05fccbc44', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/2c04052114607993bf069cf8d75686b05fccbc44', size=841), 'README.md'), (GitTreeResponseModel.GitTreeObject(path='VERSION', mode='100644', type='blob', sha='63ebd3fe34c0d27e640537087a85ef6f3776c549', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/63ebd3fe34c0d27e640537087a85ef6f3776c549', size=5), 'VERSION'), (GitTreeResponseModel.GitTreeObject(path='deploy.ps1', mode='100644', type='blob', sha='dc781b21006c62131acb120b9e01c2be753fab07', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/dc781b21006c62131acb120b9e01c2be753fab07', size=472), 'deploy.ps1'), (GitTreeResponseModel.GitTreeObject(path='deploy.sh', mode='100755', type='blob', sha='b724fbe350a86cbde5392d66715c9ac5a4164391', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b724fbe350a86cbde5392d66715c9ac5a4164391', size=420), 'deploy.sh'), (GitTreeResponseModel.GitTreeObject(path='lambda.Dockerfile', mode='100644', type='blob', sha='6c5241ea38236d40151d7de4ed36b4371ddb2820', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6c5241ea38236d40151d7de4ed36b4371ddb2820', size=438), 'lambda.Dockerfile'), (GitTreeResponseModel.GitTreeObject(path='lambda.cloudformation.yaml', mode='100644', type='blob', sha='07c93bf7848835db11c8984992c7bc1d223d088a', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/07c93bf7848835db11c8984992c7bc1d223d088a', size=1475), 'lambda.cloudformation.yaml'), (GitTreeResponseModel.GitTreeObject(path='lambda.env', mode='100644', type='blob', sha='610443c3a2f355b09b29fbbba261bf974377d114', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/610443c3a2f355b09b29fbbba261bf974377d114', size=143), 'lambda.env'), (GitTreeResponseModel.GitTreeObject(path='lambda.template.yaml', mode='100644', type='blob', sha='41accbab53f8f27860ef81e681cf74ead5c5d805', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/41accbab53f8f27860ef81e681cf74ead5c5d805', size=6347), 'lambda.template.yaml'), (GitTreeResponseModel.GitTreeObject(path='pyproject.toml', mode='100644', type='blob', sha='bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/bc70eb5c525c14de475b4d0d71c4f1b65e3f396f', size=31), 'pyproject.toml'), (GitTreeResponseModel.GitTreeObject(path='requirements.txt', mode='100644', type='blob', sha='6aba38b4968aaf87683700c6ddcbb08d73e92729', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/6aba38b4968aaf87683700c6ddcbb08d73e92729', size=300), 'requirements.txt'), (GitTreeResponseModel.GitTreeObject(path='requirements_dev.txt', mode='100644', type='blob', sha='b14d6b52b283fde18c8319b217ba6513af8f2487', url='https://api.github.com/repos/inhumantsar/tacostats/git/blobs/b14d6b52b283fde18c8319b217ba6513af8f2487', size=44), 'requirements_dev.txt'), (GitTreeResponseModel.GitTreeObject(path='samconfig.toml', mode='100644', type='blob', sha='7a126942fdb22f9e79937a3c035a2c3fef322a1d', ...
# got 36 blobs
# Time to get blobs ([('.bumpversion.cfg', 199), ('.dockerignore', 75), ('.python-version', 10), ('README.md', 841), ('VERSION', 5), ('deploy.ps1', 472), ('deploy.sh', 420), ('lambda.Dockerfile', 438), ('lambda.cloudformation.yaml', 1475), ('lambda.env', 143)]): 0.67 seconds
# generating document for .bumpversion.cfg
# got 199 characters- adding to documents - .bumpversion.cfg
# generating document for .dockerignore
# got 75 characters- adding to documents - .dockerignore
# generating document for .python-version
# got 10 characters- adding to documents - .python-version
# generating document for README.md
# got 841 characters- adding to documents - README.md
# generating document for VERSION
# got 5 characters- adding to documents - VERSION
# generating document for deploy.ps1
# got 472 characters- adding to documents - deploy.ps1
# generating document for deploy.sh
# got 420 characters- adding to documents - deploy.sh
# generating document for lambda.Dockerfile
# got 438 characters- adding to documents - lambda.Dockerfile
# generating document for lambda.cloudformation.yaml
# got 1475 characters- adding to documents - lambda.cloudformation.yaml
# generating document for lambda.env
# got 143 characters- adding to documents - lambda.env
# Time to get blobs ([('lambda.template.yaml', 6347), ('pyproject.toml', 31), ('requirements.txt', 300), ('requirements_dev.txt', 44), ('samconfig.toml', 799), ('__init__.py', 0), ('config.py', 6247), ('harvester.py', 1019), ('keywords.py', 8017), ('__init__.py', 0)]): 0.69 seconds
# generating document for lambda.template.yaml
# got 6347 characters- adding to documents - lambda.template.yaml
# generating document for pyproject.toml
# got 31 characters- adding to documents - pyproject.toml
# generating document for requirements.txt
# got 300 characters- adding to documents - requirements.txt
# generating document for requirements_dev.txt
# got 44 characters- adding to documents - requirements_dev.txt
# generating document for samconfig.toml
# got 799 characters- adding to documents - samconfig.toml
# generating document for tacostats/__init__.py
# got 0 characters- adding to documents - tacostats/__init__.py
# generating document for tacostats/config.py
# got 6246 characters- adding to documents - tacostats/config.py
# generating document for tacostats/harvester.py
# got 1019 characters- adding to documents - tacostats/harvester.py
# generating document for tacostats/keywords.py
# got 8017 characters- adding to documents - tacostats/keywords.py
# generating document for tacostats/reddit/__init__.py
# got 0 characters- adding to documents - tacostats/reddit/__init__.py
# Time to get blobs ([('dt.py', 7452), ('report.py', 2162), ('stats.py', 12137), ('__init__.py', 1322), ('local.py', 1802), ('s3.py', 3784), ('census.md.j2', 413), ('keywords.md.j2', 990), ('memeiest.md.j2', 1138), ('template.md.j2', 4579)]): 0.69 seconds
# generating document for tacostats/reddit/dt.py
# got 7452 characters- adding to documents - tacostats/reddit/dt.py
# generating document for tacostats/reddit/report.py
# got 2162 characters- adding to documents - tacostats/reddit/report.py
# generating document for tacostats/stats.py
# got 12121 characters- adding to documents - tacostats/stats.py
# generating document for tacostats/statsio/__init__.py
# got 1322 characters- adding to documents - tacostats/statsio/__init__.py
# generating document for tacostats/statsio/local.py
# got 1802 characters- adding to documents - tacostats/statsio/local.py
# generating document for tacostats/statsio/s3.py
# got 3784 characters- adding to documents - tacostats/statsio/s3.py
# generating document for tacostats/templates/census.md.j2
# got 397 characters- adding to documents - tacostats/templates/census.md.j2
# generating document for tacostats/templates/keywords.md.j2
# got 985 characters- adding to documents - tacostats/templates/keywords.md.j2
# generating document for tacostats/templates/memeiest.md.j2
# got 1121 characters- adding to documents - tacostats/templates/memeiest.md.j2
# generating document for tacostats/templates/template.md.j2
# got 4381 characters- adding to documents - tacostats/templates/template.md.j2
# Time to get blobs ([('userstats.md.j2', 971), ('userstats.py', 6996), ('util.py', 1395), ('__init__.py', 0), ('test_statsio.py', 1245), ('utils.py', 348)]): 0.54 seconds
# generating document for tacostats/templates/userstats.md.j2
# got 971 characters- adding to documents - tacostats/templates/userstats.md.j2
# generating document for tacostats/userstats.py
# got 6996 characters- adding to documents - tacostats/userstats.py
# generating document for tacostats/util.py
# got 1377 characters- adding to documents - tacostats/util.py
# generating document for test/__init__.py
# got 0 characters- adding to documents - test/__init__.py
# generating document for test/test_statsio.py
# got 1245 characters- adding to documents - test/test_statsio.py
# generating document for test/utils.py
# got 348 characters- adding to documents - test/utils.py
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total embedding token usage: 32893 tokens
# > [build_index_from_nodes] Total embedding token usage: 32893 tokens
# > [build_index_from_nodes] Total embedding token usage: 32893 tokens
# > [build_index_from_nodes] Total embedding token usage: 32893 tokens
# > [build_index_from_nodes] Total embedding token usage: 32893 tokens
# > [build_index_from_nodes] Total embedding token usage: 32893 tokens
# > [build_index_from_nodes] Total embedding token usage: 32893 tokens

# %% [markdown]
# ## Simulate a GitHub issue

# %%
from llama_index import QueryMode


gpt4_resp = gpt4_index.query(f"{PROMPT}. Pretend you are actually updating the file yourself and respond with the updated contents of the file in its entirety. Do not use markdown.", verbose=True)
# logger.info(resp)
display(gpt4_resp.response)
# Out:
# > Got node text: file_path: lambda.template.yaml
# file_name: lambda.template.yaml
#
# AWSTemplateFormatVersion: "2010-09-09"
# Transform: AWS::Serverless-2016-10-31
# Description: >
#   tacostats v1.5.4
#
#   periodically ...
# INFO:llama_index.token_counter.token_counter:> [query] Total LLM token usage: 5793 tokens
# > [query] Total LLM token usage: 5793 tokens
# > [query] Total LLM token usage: 5793 tokens
# > [query] Total LLM token usage: 5793 tokens
# > [query] Total LLM token usage: 5793 tokens
# > [query] Total LLM token usage: 5793 tokens
# > [query] Total LLM token usage: 5793 tokens
# INFO:llama_index.token_counter.token_counter:> [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# > [query] Total embedding token usage: 51 tokens
# 'AWSTemplateFormatVersion: "2010-09-09"\nTransform: AWS::Serverless-2016-10-31\nDescription: >\n  tacostats v1.5.4\n\n  periodically grab comments from the r/neoliberal DT and gather some basic statistics\n\n# More info about Globals: https://github.com/awslabs/serverless-application-model/blob/master/docs/globals.rst\nGlobals:\n  Function:\n    Timeout: 900\n\nResources:\n  ###############\n  # Harvester\n  ###############\n  Harvester:\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction\n    Properties:\n      PackageType: Image\n      MemorySize: 512\n      ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4\n      ImageConfig:\n        Command:\n          - tacostats.harvester.lambda_handler\n      Role: arn:aws:iam::390721581096:role/tacostats\n      Events:\n        Cron:\n          Type: Schedule\n          Properties:\n            Schedule: cron(55/30 * * * ? *)\n            Enabled: True\n    Metadata:\n      Dockerfile: lambda.Dockerfile\n      DockerContext: "."\n\n  # post a recap of yesterday\'s stats in the morning\n  HarvesterRecap:\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction\n    Properties:\n      PackageType: Image\n      MemorySize: 512\n      ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4\n      ImageConfig:\n        Command:\n          - tacostats.harvester.lambda_handler\n      Environment:\n        Variables:\n          RECAP: True\n      Role: arn:aws:iam::390721581096:role/tacostats\n      Events:\n        Cron:\n          Type: Schedule\n          Properties:\n            Schedule: cron(0 7 * * ? *)\n            Enabled: True\n    Metadata:\n      Dockerfile: lambda.Dockerfile\n      DockerContext: "."\n\n  ###############\n  # Statistics\n  ###############\n  Stats:\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction\n    Properties:\n      PackageType: Image\n      MemorySize: 256\n      ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4\n      ImageConfig:\n        Command:\n          - tacostats.stats.lambda_handler\n      Role: arn:aws:iam::390721581096:role/tacostats\n      Environment:\n        Variables:\n          USE_EXISTING: True\n      Events:\n        # schedules in utc, et equivs: 12,16,21\n        Cron:\n          Type: Schedule\n          Properties:\n            Schedule: cron(0 16,22,1 * * ? *)\n            Enabled: True\n    Metadata:\n      Dockerfile: lambda.Dockerfile\n      DockerContext: "."\n\n  # post a recap of yesterday\'s stats in the morning\n  StatsRecap:\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction\n    Properties:\n      PackageType: Image\n      MemorySize: 256\n      ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4\n      ImageConfig:\n        Command:\n          - tacostats.stats.lambda_handler\n      Environment:\n        Variables:\n          RECAP: True\n          USE_EXISTING: True\n      Role: arn:aws:iam::390721581096:role/tacostats\n      Events:\n        # schedules in utc, 9et\n        Cron:\n          Type: Schedule\n          Properties:\n            Schedule: cron(0 13 * * ? *)\n            Enabled: True\n    Metadata:\n      Dockerfile: lambda.Dockerfile\n      DockerContext: "."\n\n  ###############\n  # Keywords\n  ###############\n  Keywords:\n    Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverless ...

# %% [markdown]
# ### Results
#
# GPT-4 definitely did the thing. However, gpt-3.5-turbo came back with he exact same output in less time. It might be that GPT4 is more reliable or it might be that llama-index is actually just not that good. I feel like I get better results from GPT4 in chatgpt.
#
# In the output below, note that it *didn't* create a new Globals entry for MemorySize, which is something GPT3 had a habit of doing, but it *did* update UserStats for some reason, which is also something GPT3 had a habit of doing...
#
# ```yaml
# AWSTemplateFormatVersion: "2010-09-09"
# Transform: AWS::Serverless-2016-10-31
# Description: >
#   tacostats v1.5.4
#
#   periodically grab comments from the r/neoliberal DT and gather some basic statistics
#
# # More info about Globals: https://github.com/awslabs/serverless-application-model/blob/master/docs/globals.rst
# Globals:
#   Function:
#     Timeout: 900
#
# Resources:
#   ###############
#   # Harvester
#   ###############
#   Harvester:
#     Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction
#     Properties:
#       PackageType: Image
#       MemorySize: 512
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.harvester.lambda_handler
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(55/30 * * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   # post a recap of yesterday\'s stats in the morning
#   HarvesterRecap:
#     Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction
#     Properties:
#       PackageType: Image
#       MemorySize: 512
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.harvester.lambda_handler
#       Environment:
#         Variables:
#           RECAP: True
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(0 7 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   ###############
#   # Statistics
#   ###############
#   Stats:
#     Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction
#     Properties:
#       PackageType: Image
#       MemorySize: 256
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.stats.lambda_handler
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Environment:
#         Variables:
#           USE_EXISTING: True
#       Events:
#         # schedules in utc, et equivs: 12,16,21
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(0 16,22,1 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   # post a recap of yesterday\'s stats in the morning
#   StatsRecap:
#     Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction
#     Properties:
#       PackageType: Image
#       MemorySize: 256
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.stats.lambda_handler
#       Environment:
#         Variables:
#           RECAP: True
#           USE_EXISTING: True
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         # schedules in utc, 9et
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(0 13 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   ###############
#   # Keywords
#   ###############
#   Keywords:
#     Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction
#     Properties:
#       PackageType: Image
#       MemorySize: 384
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.keywords.lambda_handler
#       Environment:
#         Variables:
#           USE_EXISTING: True
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(20 20 * * ? *) # et equiv: 16:20
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   # post a recap of yesterday\'s keywords in the morning
#   KeywordsRecap:
#     Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction
#     Properties:
#       PackageType: Image
#       MemorySize: 384
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.keywords.lambda_handler
#       Environment:
#         Variables:
#           RECAP: True
#           USE_EXISTING: True
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         # schedules in utc, 10et
#         Cron:
#           Type: Schedule
#           Properties:
#             Schedule: cron(0 14 * * ? *)
#             Enabled: True
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
#
#   ###############
#   # UserStats
#   ###############
#   UserStats:
#     Type: AWS::Serverless::Function # More info about Function Resource: https://github.com/awslabs/serverless-application-model/blob/master/versions/2016-10-31.md#awsserverlessfunction
#     Properties:
#       Timeout: 300
#       PackageType: Image
#       MemorySize: 512
#       ImageUri: 390721581096.dkr.ecr.us-east-2.amazonaws.com/tacostats:v1.5.4
#       ImageConfig:
#         Command:
#           - tacostats.userstats.lambda_handler
#       Role: arn:aws:iam::390721581096:role/tacostats
#       Events:
#         Queue:
#           Type: SQS
#           Properties:
#             Queue: arn:aws:sqs:us-east-2:390721581096:tacostats-pinger
#             BatchSize: 10
#             Enabled: true
#     Metadata:
#       Dockerfile: lambda.Dockerfile
#       DockerContext: "."
# ```
